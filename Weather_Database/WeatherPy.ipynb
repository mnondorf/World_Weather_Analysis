# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 594

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grand-santi
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | mareeba
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | beloha
# Processing Record 8 of Set 1 | touros
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | buraydah
# Processing Record 12 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | tabou
# Processing Record 15 of Set 1 | belyy yar
# Processing Record 16 of Set 1 | zhangye
# Processing Record 17 of Set 1 | ajdabiya
# Processing Record 18 of Set 1 | lavrentiya
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | harper
# Processing Record 21 of Set 1 | delta del tigre
# Processing Record 22 of Set 1 | sinnamary
# Processing Record 23 of Set 1 | clyde river
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | kloulklubed
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | vila franca do campo
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | voloshka
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | aklavik
# Processing Record 33 of Set 1 | cabo san lucas
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | haines junction
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | bereda
# Processing Record 40 of Set 1 | palmer
# Processing Record 41 of Set 1 | anito
# Processing Record 42 of Set 1 | port hardy
# Processing Record 43 of Set 1 | bengkulu
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | ahipara
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | havoysund
# Processing Record 48 of Set 1 | hasaki
# Processing Record 49 of Set 1 | doba
# Processing Record 50 of Set 1 | kasongo-lunda
# Processing Record 1 of Set 2 | portland
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | alappuzha
# Processing Record 4 of Set 2 | verkhnyaya toyma
# Processing Record 5 of Set 2 | mundo novo
# Processing Record 6 of Set 2 | aksu
# Processing Record 7 of Set 2 | illapel
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | pevek
# Processing Record 10 of Set 2 | novomikhaylovskiy
# Processing Record 11 of Set 2 | constantine
# Processing Record 12 of Set 2 | luderitz
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | buenos aires
# Processing Record 16 of Set 2 | kasese
# Processing Record 17 of Set 2 | aitape
# Processing Record 18 of Set 2 | subotica
# Processing Record 19 of Set 2 | emet
# Processing Record 20 of Set 2 | songjianghe
# Processing Record 21 of Set 2 | araceli
# Processing Record 22 of Set 2 | yabrud
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | bonthe
# Processing Record 25 of Set 2 | cayenne
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | sioux lookout
# Processing Record 28 of Set 2 | formosa
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | marawi
# Processing Record 32 of Set 2 | tuatapere
# Processing Record 33 of Set 2 | durusu
# Processing Record 34 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 2 | coquimbo
# Processing Record 36 of Set 2 | srandakan
# Processing Record 37 of Set 2 | honningsvag
# Processing Record 38 of Set 2 | saint anthony
# Processing Record 39 of Set 2 | kirakira
# Processing Record 40 of Set 2 | narsaq
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | yulara
# Processing Record 44 of Set 2 | greymouth
# Processing Record 45 of Set 2 | avera
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | ponta do sol
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | betong
# Processing Record 1 of Set 3 | araouane
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | san lorenzo
# Processing Record 4 of Set 3 | bredasdorp
# Processing Record 5 of Set 3 | pemba
# Processing Record 6 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 3 | cape town
# Processing Record 8 of Set 3 | nsanje
# Processing Record 9 of Set 3 | ust-abakan
# Processing Record 10 of Set 3 | aykhal
# Processing Record 11 of Set 3 | khorixas
# Processing Record 12 of Set 3 | latung
# Processing Record 13 of Set 3 | severo-yeniseyskiy
# Processing Record 14 of Set 3 | mackenzie
# Processing Record 15 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 3 | yumen
# Processing Record 17 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 3 | plettenberg bay
# Processing Record 19 of Set 3 | saint george
# Processing Record 20 of Set 3 | camocim
# Processing Record 21 of Set 3 | iskateley
# Processing Record 22 of Set 3 | upernavik
# Processing Record 23 of Set 3 | kaitangata
# Processing Record 24 of Set 3 | ancud
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | tilichiki
# Processing Record 27 of Set 3 | maku
# Processing Record 28 of Set 3 | hay river
# Processing Record 29 of Set 3 | esterhazy
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | candelaria
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | coihaique
# Processing Record 34 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 3 | bosaso
# Processing Record 36 of Set 3 | eureka
# Processing Record 37 of Set 3 | hilo
# Processing Record 38 of Set 3 | olafsvik
# Processing Record 39 of Set 3 | arawa
# Processing Record 40 of Set 3 | itarema
# Processing Record 41 of Set 3 | rehnan
# Processing Record 42 of Set 3 | mehamn
# Processing Record 43 of Set 3 | longyearbyen
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | codrington
# Processing Record 46 of Set 3 | dikson
# Processing Record 47 of Set 3 | maykain
# City not found. Skipping...
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | severo-kurilsk
# Processing Record 50 of Set 3 | methoni
# Processing Record 1 of Set 4 | coromandel
# Processing Record 2 of Set 4 | dunedin
# Processing Record 3 of Set 4 | norman wells
# Processing Record 4 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 5 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 4 | anadyr
# Processing Record 7 of Set 4 | birao
# Processing Record 8 of Set 4 | ourinhos
# Processing Record 9 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 4 | axim
# Processing Record 11 of Set 4 | naze
# Processing Record 12 of Set 4 | faanui
# Processing Record 13 of Set 4 | hovd
# Processing Record 14 of Set 4 | kavieng
# Processing Record 15 of Set 4 | oum hadjer
# Processing Record 16 of Set 4 | baherden
# Processing Record 17 of Set 4 | san patricio
# Processing Record 18 of Set 4 | gat
# Processing Record 19 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 4 | east london
# Processing Record 21 of Set 4 | waingapu
# Processing Record 22 of Set 4 | namatanai
# Processing Record 23 of Set 4 | santa lucia
# Processing Record 24 of Set 4 | lebu
# Processing Record 25 of Set 4 | udachnyy
# Processing Record 26 of Set 4 | egvekinot
# Processing Record 27 of Set 4 | mogadouro
# Processing Record 28 of Set 4 | aljezur
# Processing Record 29 of Set 4 | miri
# Processing Record 30 of Set 4 | mahon
# Processing Record 31 of Set 4 | bethel
# Processing Record 32 of Set 4 | nanakuli
# Processing Record 33 of Set 4 | katsuura
# Processing Record 34 of Set 4 | abu samrah
# Processing Record 35 of Set 4 | ballina
# Processing Record 36 of Set 4 | ushumun
# Processing Record 37 of Set 4 | geraldton
# Processing Record 38 of Set 4 | beihai
# Processing Record 39 of Set 4 | roma
# Processing Record 40 of Set 4 | bambanglipuro
# Processing Record 41 of Set 4 | bequimao
# Processing Record 42 of Set 4 | avarua
# Processing Record 43 of Set 4 | cabinda
# Processing Record 44 of Set 4 | kharitonovo
# Processing Record 45 of Set 4 | nizwa
# Processing Record 46 of Set 4 | marana
# Processing Record 47 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 4 | glendive
# Processing Record 49 of Set 4 | mutoko
# Processing Record 50 of Set 4 | faya
# Processing Record 1 of Set 5 | ahtopol
# Processing Record 2 of Set 5 | kamsack
# Processing Record 3 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 5 | ribeira grande
# Processing Record 5 of Set 5 | kahului
# Processing Record 6 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 9 of Set 5 | nijar
# Processing Record 10 of Set 5 | nalut
# Processing Record 11 of Set 5 | viedma
# Processing Record 12 of Set 5 | umm lajj
# Processing Record 13 of Set 5 | la plata
# Processing Record 14 of Set 5 | olavarria
# Processing Record 15 of Set 5 | torbay
# Processing Record 16 of Set 5 | buta
# Processing Record 17 of Set 5 | padang
# Processing Record 18 of Set 5 | arraial do cabo
# Processing Record 19 of Set 5 | rocha
# Processing Record 20 of Set 5 | hearst
# Processing Record 21 of Set 5 | horsham
# Processing Record 22 of Set 5 | bambous virieux
# Processing Record 23 of Set 5 | kodiak
# Processing Record 24 of Set 5 | deputatskiy
# Processing Record 25 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 5 | carnarvon
# Processing Record 27 of Set 5 | vysha
# Processing Record 28 of Set 5 | harrisburg
# Processing Record 29 of Set 5 | havre-saint-pierre
# Processing Record 30 of Set 5 | phichit
# Processing Record 31 of Set 5 | tucuman
# Processing Record 32 of Set 5 | dingzhou
# Processing Record 33 of Set 5 | bathsheba
# Processing Record 34 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 35 of Set 5 | labuhan
# Processing Record 36 of Set 5 | mogwase
# Processing Record 37 of Set 5 | vila velha
# Processing Record 38 of Set 5 | canutama
# Processing Record 39 of Set 5 | santiago del estero
# Processing Record 40 of Set 5 | kamiiso
# Processing Record 41 of Set 5 | shache
# Processing Record 42 of Set 5 | iwanai
# Processing Record 43 of Set 5 | rawson
# Processing Record 44 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 45 of Set 5 | lewiston
# Processing Record 46 of Set 5 | talaya
# Processing Record 47 of Set 5 | llandrindod wells
# Processing Record 48 of Set 5 | maniitsoq
# Processing Record 49 of Set 5 | ostrovnoy
# Processing Record 50 of Set 5 | nicoya
# Processing Record 1 of Set 6 | te anau
# Processing Record 2 of Set 6 | bluff
# Processing Record 3 of Set 6 | ugoofaaru
# Processing Record 4 of Set 6 | leningradskiy
# Processing Record 5 of Set 6 | bilibino
# Processing Record 6 of Set 6 | raudeberg
# Processing Record 7 of Set 6 | grindavik
# Processing Record 8 of Set 6 | saint-philippe
# Processing Record 9 of Set 6 | ende
# Processing Record 10 of Set 6 | rabo de peixe
# Processing Record 11 of Set 6 | sao filipe
# Processing Record 12 of Set 6 | yarada
# Processing Record 13 of Set 6 | tual
# Processing Record 14 of Set 6 | qui nhon
# Processing Record 15 of Set 6 | juliaca
# Processing Record 16 of Set 6 | liyang
# Processing Record 17 of Set 6 | beringovskiy
# Processing Record 18 of Set 6 | bonoua
# Processing Record 19 of Set 6 | eston
# Processing Record 20 of Set 6 | wangaratta
# Processing Record 21 of Set 6 | caravelas
# Processing Record 22 of Set 6 | mogadishu
# Processing Record 23 of Set 6 | ningan
# City not found. Skipping...
# Processing Record 24 of Set 6 | lompoc
# Processing Record 25 of Set 6 | hohhot
# Processing Record 26 of Set 6 | san luis
# Processing Record 27 of Set 6 | sergeyevka
# Processing Record 28 of Set 6 | hokitika
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | opuwo
# Processing Record 31 of Set 6 | nisia floresta
# Processing Record 32 of Set 6 | staryy nadym
# Processing Record 33 of Set 6 | huron
# Processing Record 34 of Set 6 | karpogory
# Processing Record 35 of Set 6 | rio cuarto
# Processing Record 36 of Set 6 | zalantun
# Processing Record 37 of Set 6 | vanavara
# Processing Record 38 of Set 6 | qaanaaq
# Processing Record 39 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 40 of Set 6 | pangnirtung
# Processing Record 41 of Set 6 | khatanga
# Processing Record 42 of Set 6 | bardsir
# Processing Record 43 of Set 6 | esperance
# Processing Record 44 of Set 6 | talnakh
# Processing Record 45 of Set 6 | airai
# Processing Record 46 of Set 6 | salalah
# Processing Record 47 of Set 6 | nikolskoye
# Processing Record 48 of Set 6 | mulege
# Processing Record 49 of Set 6 | kahama
# Processing Record 50 of Set 6 | duz
# City not found. Skipping...
# Processing Record 1 of Set 7 | galeana
# Processing Record 2 of Set 7 | dubbo
# Processing Record 3 of Set 7 | sao joao da barra
# Processing Record 4 of Set 7 | semnan
# Processing Record 5 of Set 7 | mikkeli
# Processing Record 6 of Set 7 | cangucu
# Processing Record 7 of Set 7 | los llanos de aridane
# Processing Record 8 of Set 7 | neuquen
# Processing Record 9 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 7 | flinders
# Processing Record 11 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 7 | saurimo
# Processing Record 13 of Set 7 | zhigansk
# Processing Record 14 of Set 7 | rivera
# Processing Record 15 of Set 7 | raichur
# Processing Record 16 of Set 7 | saldanha
# Processing Record 17 of Set 7 | lukang
# Processing Record 18 of Set 7 | santa cruz
# Processing Record 19 of Set 7 | reguengos de monsaraz
# Processing Record 20 of Set 7 | acapulco
# Processing Record 21 of Set 7 | benton harbor
# Processing Record 22 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 7 | mbulu
# Processing Record 24 of Set 7 | alikalia
# Processing Record 25 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 7 | santiago
# Processing Record 27 of Set 7 | siguiri
# Processing Record 28 of Set 7 | cidreira
# Processing Record 29 of Set 7 | rio grande
# Processing Record 30 of Set 7 | lagos
# Processing Record 31 of Set 7 | goderich
# Processing Record 32 of Set 7 | henties bay
# Processing Record 33 of Set 7 | martapura
# Processing Record 34 of Set 7 | lerwick
# Processing Record 35 of Set 7 | podor
# Processing Record 36 of Set 7 | koshki
# Processing Record 37 of Set 7 | jaciara
# Processing Record 38 of Set 7 | cairo
# Processing Record 39 of Set 7 | alofi
# Processing Record 40 of Set 7 | salinas
# Processing Record 41 of Set 7 | sao francisco
# Processing Record 42 of Set 7 | kulhudhuffushi
# Processing Record 43 of Set 7 | panzhihua
# Processing Record 44 of Set 7 | kensington
# Processing Record 45 of Set 7 | moron
# Processing Record 46 of Set 7 | caucaia
# Processing Record 47 of Set 7 | puerto madryn
# Processing Record 48 of Set 7 | lugovoy
# Processing Record 49 of Set 7 | saint-georges
# Processing Record 50 of Set 7 | mortara
# Processing Record 1 of Set 8 | meulaboh
# Processing Record 2 of Set 8 | muromtsevo
# Processing Record 3 of Set 8 | merauke
# Processing Record 4 of Set 8 | port blair
# Processing Record 5 of Set 8 | waddan
# Processing Record 6 of Set 8 | dingle
# Processing Record 7 of Set 8 | polazna
# Processing Record 8 of Set 8 | lashio
# Processing Record 9 of Set 8 | alice springs
# Processing Record 10 of Set 8 | fortuna
# Processing Record 11 of Set 8 | port lincoln
# Processing Record 12 of Set 8 | skibbereen
# Processing Record 13 of Set 8 | eydhafushi
# Processing Record 14 of Set 8 | kovdor
# Processing Record 15 of Set 8 | constitucion
# Processing Record 16 of Set 8 | palana
# Processing Record 17 of Set 8 | kruisfontein
# Processing Record 18 of Set 8 | sitka
# Processing Record 19 of Set 8 | komsomolskiy
# Processing Record 20 of Set 8 | nemuro
# Processing Record 21 of Set 8 | hoquiam
# Processing Record 22 of Set 8 | karachi
# Processing Record 23 of Set 8 | fukue
# Processing Record 24 of Set 8 | dakar
# Processing Record 25 of Set 8 | rawlins
# Processing Record 26 of Set 8 | albstadt
# Processing Record 27 of Set 8 | paragominas
# Processing Record 28 of Set 8 | treinta y tres
# Processing Record 29 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 8 | kirensk
# Processing Record 32 of Set 8 | santa vitoria do palmar
# Processing Record 33 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 8 | nome
# Processing Record 35 of Set 8 | hervey bay
# Processing Record 36 of Set 8 | pacific grove
# Processing Record 37 of Set 8 | dalneye konstantinovo
# City not found. Skipping...
# Processing Record 38 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 8 | kieta
# Processing Record 40 of Set 8 | alamogordo
# Processing Record 41 of Set 8 | tangi
# Processing Record 42 of Set 8 | uhlove
# Processing Record 43 of Set 8 | cherskiy
# Processing Record 44 of Set 8 | tawzar
# City not found. Skipping...
# Processing Record 45 of Set 8 | berlevag
# Processing Record 46 of Set 8 | sicamous
# Processing Record 47 of Set 8 | slavsk
# Processing Record 48 of Set 8 | verkhnyaya inta
# Processing Record 49 of Set 8 | manbij
# Processing Record 50 of Set 8 | terra santa
# Processing Record 1 of Set 9 | tlaltenango
# Processing Record 2 of Set 9 | beitbridge
# Processing Record 3 of Set 9 | tanjong sepat
# City not found. Skipping...
# Processing Record 4 of Set 9 | provideniya
# Processing Record 5 of Set 9 | ahuimanu
# Processing Record 6 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 9 | burica
# City not found. Skipping...
# Processing Record 8 of Set 9 | chiguiri arriba
# City not found. Skipping...
# Processing Record 9 of Set 9 | kungurtug
# Processing Record 10 of Set 9 | seymchan
# Processing Record 11 of Set 9 | areni
# Processing Record 12 of Set 9 | naranjal
# Processing Record 13 of Set 9 | shelburne
# Processing Record 14 of Set 9 | chambar
# Processing Record 15 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 9 | dabakala
# Processing Record 17 of Set 9 | kudahuvadhoo
# Processing Record 18 of Set 9 | vardo
# Processing Record 19 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 9 | romny
# Processing Record 21 of Set 9 | yaan
# Processing Record 22 of Set 9 | altamira
# Processing Record 23 of Set 9 | arman
# Processing Record 24 of Set 9 | burayevo
# Processing Record 25 of Set 9 | victoria
# Processing Record 26 of Set 9 | lochem
# Processing Record 27 of Set 9 | waipawa
# Processing Record 28 of Set 9 | isangel
# Processing Record 29 of Set 9 | contamana
# Processing Record 30 of Set 9 | masuguru
# Processing Record 31 of Set 9 | tura
# Processing Record 32 of Set 9 | tsumeb
# Processing Record 33 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 34 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 9 | delhi
# Processing Record 36 of Set 9 | monrovia
# Processing Record 37 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 9 | tank
# Processing Record 39 of Set 9 | lata
# Processing Record 40 of Set 9 | bandar-e anzali
# Processing Record 41 of Set 9 | ewa beach
# Processing Record 42 of Set 9 | korop
# Processing Record 43 of Set 9 | baiao
# Processing Record 44 of Set 9 | ayagoz
# Processing Record 45 of Set 9 | pisco
# Processing Record 46 of Set 9 | iracoubo
# Processing Record 47 of Set 9 | mount isa
# Processing Record 48 of Set 9 | vao
# Processing Record 49 of Set 9 | namibe
# Processing Record 50 of Set 9 | stromness
# Processing Record 1 of Set 10 | ulladulla
# Processing Record 2 of Set 10 | lerum
# Processing Record 3 of Set 10 | arlit
# Processing Record 4 of Set 10 | bandarbeyla
# Processing Record 5 of Set 10 | salinopolis
# Processing Record 6 of Set 10 | la seyne-sur-mer
# Processing Record 7 of Set 10 | kiama
# Processing Record 8 of Set 10 | pandan niog
# Processing Record 9 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 10 | ustye
# Processing Record 11 of Set 10 | lagoa
# Processing Record 12 of Set 10 | santa fe
# Processing Record 13 of Set 10 | nizhniy kuranakh
# Processing Record 14 of Set 10 | pacifica
# Processing Record 15 of Set 10 | brae
# Processing Record 16 of Set 10 | chernyshevskiy
# Processing Record 17 of Set 10 | wicklow
# Processing Record 18 of Set 10 | wuwei
# Processing Record 19 of Set 10 | adilcevaz
# Processing Record 20 of Set 10 | road town
# Processing Record 21 of Set 10 | ambon
# Processing Record 22 of Set 10 | husavik
# Processing Record 23 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 10 | novopetrovskoye
# Processing Record 25 of Set 10 | yanam
# Processing Record 26 of Set 10 | slagelse
# Processing Record 27 of Set 10 | roald
# Processing Record 28 of Set 10 | puro
# Processing Record 29 of Set 10 | amudat
# Processing Record 30 of Set 10 | sayyan
# Processing Record 31 of Set 10 | lakatoro
# Processing Record 32 of Set 10 | walcz
# Processing Record 33 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 34 of Set 10 | enkoping
# Processing Record 35 of Set 10 | humaita
# Processing Record 36 of Set 10 | luwingu
# Processing Record 37 of Set 10 | saint-pierre
# Processing Record 38 of Set 10 | kisanga
# Processing Record 39 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 10 | nishihara
# Processing Record 41 of Set 10 | talakan
# Processing Record 42 of Set 10 | santa rosa
# Processing Record 43 of Set 10 | umkomaas
# Processing Record 44 of Set 10 | oxford
# Processing Record 45 of Set 10 | san cristobal
# Processing Record 46 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 10 | warrington
# Processing Record 48 of Set 10 | san pedro
# Processing Record 49 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 50 of Set 10 | hofn
# Processing Record 1 of Set 11 | bonavista
# Processing Record 2 of Set 11 | krasnoarmeysk
# Processing Record 3 of Set 11 | tahta
# Processing Record 4 of Set 11 | tchollire
# Processing Record 5 of Set 11 | nadvoitsy
# Processing Record 6 of Set 11 | okhotsk
# Processing Record 7 of Set 11 | klaksvik
# Processing Record 8 of Set 11 | urumqi
# Processing Record 9 of Set 11 | mayumba
# Processing Record 10 of Set 11 | campbell river
# Processing Record 11 of Set 11 | sri aman
# Processing Record 12 of Set 11 | tripoli
# Processing Record 13 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 14 of Set 11 | peski
# Processing Record 15 of Set 11 | kathu
# Processing Record 16 of Set 11 | hualmay
# Processing Record 17 of Set 11 | gelibolu
# Processing Record 18 of Set 11 | bekasi
# Processing Record 19 of Set 11 | kuching
# Processing Record 20 of Set 11 | kinanah
# City not found. Skipping...
# Processing Record 21 of Set 11 | shenjiamen
# Processing Record 22 of Set 11 | adrar
# Processing Record 23 of Set 11 | paamiut
# Processing Record 24 of Set 11 | broome
# Processing Record 25 of Set 11 | georgiyevka
# Processing Record 26 of Set 11 | kande
# Processing Record 27 of Set 11 | kasane
# Processing Record 28 of Set 11 | paracuru
# Processing Record 29 of Set 11 | turukhansk
# Processing Record 30 of Set 11 | mount gambier
# Processing Record 31 of Set 11 | arnes
# Processing Record 32 of Set 11 | haicheng
# Processing Record 33 of Set 11 | kouango
# Processing Record 34 of Set 11 | wilmington
# Processing Record 35 of Set 11 | kokstad
# Processing Record 36 of Set 11 | sete
# Processing Record 37 of Set 11 | akita
# Processing Record 38 of Set 11 | tobane
# Processing Record 39 of Set 11 | irtyshskiy
# Processing Record 40 of Set 11 | bac lieu
# Processing Record 41 of Set 11 | pokhara
# Processing Record 42 of Set 11 | kedrovyy
# Processing Record 43 of Set 11 | korla
# Processing Record 44 of Set 11 | tonantins
# Processing Record 45 of Set 11 | surt
# Processing Record 46 of Set 11 | wolfsburg
# Processing Record 47 of Set 11 | coos bay
# Processing Record 48 of Set 11 | muntilan
# Processing Record 49 of Set 11 | port macquarie
# Processing Record 50 of Set 11 | ducheng
# Processing Record 1 of Set 12 | madaripur
# Processing Record 2 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 12 | farah
# Processing Record 4 of Set 12 | ler
# Processing Record 5 of Set 12 | gushi
# Processing Record 6 of Set 12 | tiarei
# Processing Record 7 of Set 12 | kitakata
# Processing Record 8 of Set 12 | energetik
# Processing Record 9 of Set 12 | bayji
# Processing Record 10 of Set 12 | comodoro rivadavia
# Processing Record 11 of Set 12 | hawera
# Processing Record 12 of Set 12 | mecca
# Processing Record 13 of Set 12 | anchorage
# Processing Record 14 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 12 | tecoanapa
# Processing Record 16 of Set 12 | ekibastuz
# Processing Record 17 of Set 12 | madimba
# Processing Record 18 of Set 12 | santiago de cao
# Processing Record 19 of Set 12 | danilovka
# Processing Record 20 of Set 12 | souillac
# Processing Record 21 of Set 12 | morogoro
# Processing Record 22 of Set 12 | angoche
# Processing Record 23 of Set 12 | douglas
# Processing Record 24 of Set 12 | jalu
# Processing Record 25 of Set 12 | malanje
# Processing Record 26 of Set 12 | carora
# Processing Record 27 of Set 12 | kiunga
# Processing Record 28 of Set 12 | bharatpur
# Processing Record 29 of Set 12 | moose factory
# Processing Record 30 of Set 12 | gushikawa
# Processing Record 31 of Set 12 | huarmey
# Processing Record 32 of Set 12 | palmas bellas
# Processing Record 33 of Set 12 | dudinka
# Processing Record 34 of Set 12 | bubaque
# Processing Record 35 of Set 12 | chase
# Processing Record 36 of Set 12 | peace river
# Processing Record 37 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 12 | caranavi
# Processing Record 39 of Set 12 | medveda
# Processing Record 40 of Set 12 | kaeo
# Processing Record 41 of Set 12 | heihe
# Processing Record 42 of Set 12 | inhambane
# Processing Record 43 of Set 12 | ilanskiy
# Processing Record 44 of Set 12 | lodja
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 537

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Grand-Santi   4.2500  -54.3833     72.46        98          52
# 1    Georgetown   5.4112  100.3354     78.73        93          40
# 2     Hithadhoo  -0.6000   73.0833     81.32        74         100
# 3      Hermanus -34.4187   19.2345     65.80        81          97
# 4       Mareeba -17.0000  145.4333     76.44        96         100
# 5       Ushuaia -54.8000  -68.3000     51.46        71          75
# 6        Beloha -25.1667   45.0500     70.48        84           0
# 7        Touros  -5.1989  -35.4608     81.50        74          34
# 8  Punta Arenas -53.1500  -70.9167     55.51        67           0
# 9       Iqaluit  63.7506  -68.5145    -22.27        69          20
#
#    Wind Speed Country                 Date
# 0        3.06      GF  2022-01-26 22:19:42
# 1        3.44      MY  2022-01-26 22:19:42
# 2       21.65      MV  2022-01-26 22:19:42
# 3       13.13      ZA  2022-01-26 22:19:43
# 4        2.57      AU  2022-01-26 22:19:43
# 5       32.21      AR  2022-01-26 22:19:43
# 6       14.14      MG  2022-01-26 22:19:44
# 7       13.31      BR  2022-01-26 22:19:44
# 8       29.93      CL  2022-01-26 22:15:36
# 9        2.30      CA  2022-01-26 22:19:44

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_new_df = city_data_df[new_column_order]
city_data_new_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0  Grand-Santi      GF  2022-01-26 22:19:42   4.2500  -54.3833     72.46
# 1   Georgetown      MY  2022-01-26 22:19:42   5.4112  100.3354     78.73
# 2    Hithadhoo      MV  2022-01-26 22:19:42  -0.6000   73.0833     81.32
# 3     Hermanus      ZA  2022-01-26 22:19:43 -34.4187   19.2345     65.80
# 4      Mareeba      AU  2022-01-26 22:19:43 -17.0000  145.4333     76.44
#
#    Humidity  Cloudiness  Wind Speed
# 0        98          52        3.06
# 1        93          40        3.44
# 2        74         100       21.65
# 3        81          97       13.13
# 4        96         100        2.57

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()
