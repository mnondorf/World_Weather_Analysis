# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | camacha
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | yar-sale
# Processing Record 6 of Set 1 | sirvintos
# Processing Record 7 of Set 1 | nanortalik
# Processing Record 8 of Set 1 | sarangani
# Processing Record 9 of Set 1 | lake city
# Processing Record 10 of Set 1 | sao felix do xingu
# Processing Record 11 of Set 1 | qingyuan
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | diu
# Processing Record 14 of Set 1 | talcher
# Processing Record 15 of Set 1 | ambilobe
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | mount gambier
# Processing Record 18 of Set 1 | yulara
# Processing Record 19 of Set 1 | balkhash
# Processing Record 20 of Set 1 | arman
# Processing Record 21 of Set 1 | nikolskoye
# Processing Record 22 of Set 1 | wanning
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | longkou
# Processing Record 25 of Set 1 | benguela
# Processing Record 26 of Set 1 | haimen
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | coihaique
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | touros
# Processing Record 37 of Set 1 | geraldton
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | tamale
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | raudeberg
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | pangody
# Processing Record 45 of Set 1 | solhan
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | mehamn
# Processing Record 48 of Set 1 | serenje
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | meulaboh
# Processing Record 1 of Set 2 | liku
# Processing Record 2 of Set 2 | eyrarbakki
# Processing Record 3 of Set 2 | nidzica
# Processing Record 4 of Set 2 | marawi
# Processing Record 5 of Set 2 | ondangwa
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | ribas do rio pardo
# Processing Record 8 of Set 2 | auki
# Processing Record 9 of Set 2 | carolina
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | lichinga
# Processing Record 12 of Set 2 | spilimbergo
# Processing Record 13 of Set 2 | portland
# Processing Record 14 of Set 2 | ndioum
# Processing Record 15 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | baker city
# Processing Record 19 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 2 | santo antonio do ica
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | coquimbo
# Processing Record 29 of Set 2 | acapulco
# Processing Record 30 of Set 2 | quatre cocos
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 2 | metsovon
# City not found. Skipping...
# Processing Record 33 of Set 2 | tuktoyaktuk
# Processing Record 34 of Set 2 | lima
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | shurugwi
# Processing Record 38 of Set 2 | mitsamiouli
# Processing Record 39 of Set 2 | honiara
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | aku
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | jardim
# Processing Record 44 of Set 2 | great falls
# Processing Record 45 of Set 2 | porgera
# Processing Record 46 of Set 2 | husavik
# Processing Record 47 of Set 2 | verkhnyaya toyma
# Processing Record 48 of Set 2 | platteville
# Processing Record 49 of Set 2 | iqaluit
# Processing Record 50 of Set 2 | sao filipe
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | yerbogachen
# Processing Record 3 of Set 3 | shellbrook
# Processing Record 4 of Set 3 | mirnyy
# Processing Record 5 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | pacific grove
# Processing Record 10 of Set 3 | shasta lake
# Processing Record 11 of Set 3 | tiznit
# Processing Record 12 of Set 3 | san jeronimo
# Processing Record 13 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 3 | samarai
# Processing Record 15 of Set 3 | vilyuysk
# Processing Record 16 of Set 3 | bataipora
# Processing Record 17 of Set 3 | sal rei
# Processing Record 18 of Set 3 | bandarbeyla
# Processing Record 19 of Set 3 | severo-kurilsk
# Processing Record 20 of Set 3 | valleyview
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 3 | san patricio
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | plainview
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | ostrovnoy
# Processing Record 28 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 3 | tortosa
# Processing Record 30 of Set 3 | dikson
# Processing Record 31 of Set 3 | hofn
# Processing Record 32 of Set 3 | talnakh
# Processing Record 33 of Set 3 | port blair
# Processing Record 34 of Set 3 | bhuj
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | tucuman
# Processing Record 37 of Set 3 | gizo
# Processing Record 38 of Set 3 | cidreira
# Processing Record 39 of Set 3 | gambo
# Processing Record 40 of Set 3 | mayari
# City not found. Skipping...
# Processing Record 41 of Set 3 | bull savanna
# Processing Record 42 of Set 3 | cayenne
# Processing Record 43 of Set 3 | virden
# Processing Record 44 of Set 3 | los llanos de aridane
# Processing Record 45 of Set 3 | kapaa
# Processing Record 46 of Set 3 | oswego
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | nome
# Processing Record 49 of Set 3 | dunedin
# Processing Record 50 of Set 3 | shingu
# Processing Record 1 of Set 4 | constitucion
# Processing Record 2 of Set 4 | kodiak
# Processing Record 3 of Set 4 | ariquemes
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | spassk
# Processing Record 6 of Set 4 | kilindoni
# Processing Record 7 of Set 4 | sitka
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | dongsheng
# Processing Record 10 of Set 4 | grand gaube
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | ishigaki
# Processing Record 14 of Set 4 | oktyabrskiy
# Processing Record 15 of Set 4 | pisco
# Processing Record 16 of Set 4 | marzuq
# Processing Record 17 of Set 4 | jilib
# Processing Record 18 of Set 4 | bambous virieux
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | krasnoselkup
# Processing Record 21 of Set 4 | laguna
# Processing Record 22 of Set 4 | lavrentiya
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | broome
# Processing Record 25 of Set 4 | soyo
# Processing Record 26 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | banda aceh
# Processing Record 31 of Set 4 | rocha
# Processing Record 32 of Set 4 | korocha
# Processing Record 33 of Set 4 | florida
# Processing Record 34 of Set 4 | victoria
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | bulungu
# Processing Record 37 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 4 | eyl
# Processing Record 39 of Set 4 | georgetown
# Processing Record 40 of Set 4 | usinsk
# Processing Record 41 of Set 4 | norman wells
# Processing Record 42 of Set 4 | erding
# Processing Record 43 of Set 4 | tiksi
# Processing Record 44 of Set 4 | miranorte
# City not found. Skipping...
# Processing Record 45 of Set 4 | kahului
# Processing Record 46 of Set 4 | kiev
# Processing Record 47 of Set 4 | ilulissat
# Processing Record 48 of Set 4 | tigil
# Processing Record 49 of Set 4 | maracas
# Processing Record 50 of Set 4 | tilichiki
# Processing Record 1 of Set 5 | sujangarh
# Processing Record 2 of Set 5 | baruun-urt
# Processing Record 3 of Set 5 | dalinghe
# City not found. Skipping...
# Processing Record 4 of Set 5 | dudinka
# Processing Record 5 of Set 5 | sistranda
# Processing Record 6 of Set 5 | kavaratti
# Processing Record 7 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 5 | galeana
# Processing Record 9 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 5 | palmer
# Processing Record 11 of Set 5 | jardim de piranhas
# Processing Record 12 of Set 5 | arraial do cabo
# Processing Record 13 of Set 5 | santa ines
# Processing Record 14 of Set 5 | lorengau
# Processing Record 15 of Set 5 | montbrison
# Processing Record 16 of Set 5 | ippy
# Processing Record 17 of Set 5 | ucluelet
# Processing Record 18 of Set 5 | altayskoye
# Processing Record 19 of Set 5 | dali
# Processing Record 20 of Set 5 | yelizovo
# Processing Record 21 of Set 5 | muli
# Processing Record 22 of Set 5 | mayor pablo lagerenza
# Processing Record 23 of Set 5 | mantua
# Processing Record 24 of Set 5 | taraz
# Processing Record 25 of Set 5 | hanna
# Processing Record 26 of Set 5 | nantucket
# Processing Record 27 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 5 | tirano
# Processing Record 29 of Set 5 | byron bay
# Processing Record 30 of Set 5 | hambantota
# Processing Record 31 of Set 5 | uberlandia
# Processing Record 32 of Set 5 | tuni
# Processing Record 33 of Set 5 | yaounde
# Processing Record 34 of Set 5 | mount isa
# Processing Record 35 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 37 of Set 5 | presidente medici
# Processing Record 38 of Set 5 | roald
# Processing Record 39 of Set 5 | ponta do sol
# Processing Record 40 of Set 5 | pangnirtung
# Processing Record 41 of Set 5 | labytnangi
# Processing Record 42 of Set 5 | jasper
# Processing Record 43 of Set 5 | port-cartier
# Processing Record 44 of Set 5 | arrecife
# Processing Record 45 of Set 5 | port hardy
# Processing Record 46 of Set 5 | kondopoga
# Processing Record 47 of Set 5 | te anau
# Processing Record 48 of Set 5 | cabano
# Processing Record 49 of Set 5 | chervona sloboda
# Processing Record 50 of Set 5 | iznoski
# Processing Record 1 of Set 6 | college
# Processing Record 2 of Set 6 | ust-nera
# Processing Record 3 of Set 6 | manggar
# Processing Record 4 of Set 6 | pathein
# Processing Record 5 of Set 6 | sao miguel do araguaia
# Processing Record 6 of Set 6 | hasaki
# Processing Record 7 of Set 6 | opuwo
# Processing Record 8 of Set 6 | taltal
# Processing Record 9 of Set 6 | san cristobal
# Processing Record 10 of Set 6 | half moon bay
# Processing Record 11 of Set 6 | narsaq
# Processing Record 12 of Set 6 | vostok
# Processing Record 13 of Set 6 | iralaya
# Processing Record 14 of Set 6 | saint george
# Processing Record 15 of Set 6 | saint-joseph
# Processing Record 16 of Set 6 | vila
# Processing Record 17 of Set 6 | port lincoln
# Processing Record 18 of Set 6 | flin flon
# Processing Record 19 of Set 6 | clyde river
# Processing Record 20 of Set 6 | bundaberg
# Processing Record 21 of Set 6 | miraflores
# Processing Record 22 of Set 6 | johannesburg
# Processing Record 23 of Set 6 | najran
# Processing Record 24 of Set 6 | hualmay
# Processing Record 25 of Set 6 | carnarvon
# Processing Record 26 of Set 6 | vestmannaeyjar
# Processing Record 27 of Set 6 | tirumullaivasal
# Processing Record 28 of Set 6 | waipawa
# Processing Record 29 of Set 6 | mana
# Processing Record 30 of Set 6 | tomatlan
# Processing Record 31 of Set 6 | truro
# Processing Record 32 of Set 6 | bolivar
# Processing Record 33 of Set 6 | tam ky
# Processing Record 34 of Set 6 | foix
# Processing Record 35 of Set 6 | puerto colombia
# Processing Record 36 of Set 6 | kapit
# Processing Record 37 of Set 6 | ridgecrest
# Processing Record 38 of Set 6 | airai
# Processing Record 39 of Set 6 | hoyanger
# Processing Record 40 of Set 6 | chapais
# Processing Record 41 of Set 6 | mende
# Processing Record 42 of Set 6 | port-gentil
# Processing Record 43 of Set 6 | san pietro in casale
# Processing Record 44 of Set 6 | vardo
# Processing Record 45 of Set 6 | dayong
# Processing Record 46 of Set 6 | ewa beach
# Processing Record 47 of Set 6 | serebriya
# Processing Record 48 of Set 6 | itarema
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 50 of Set 6 | saldanha
# Processing Record 1 of Set 7 | buon me thuot
# City not found. Skipping...
# Processing Record 2 of Set 7 | aljezur
# Processing Record 3 of Set 7 | mayumba
# Processing Record 4 of Set 7 | teya
# Processing Record 5 of Set 7 | itatiaia
# Processing Record 6 of Set 7 | paamiut
# Processing Record 7 of Set 7 | birjand
# Processing Record 8 of Set 7 | pochutla
# Processing Record 9 of Set 7 | goteborg
# City not found. Skipping...
# Processing Record 10 of Set 7 | richards bay
# Processing Record 11 of Set 7 | suez
# Processing Record 12 of Set 7 | alta floresta
# Processing Record 13 of Set 7 | kushiro
# Processing Record 14 of Set 7 | swift current
# Processing Record 15 of Set 7 | maniitsoq
# Processing Record 16 of Set 7 | solok
# Processing Record 17 of Set 7 | bocaiuva
# Processing Record 18 of Set 7 | manoel urbano
# Processing Record 19 of Set 7 | sao gabriel da cachoeira
# Processing Record 20 of Set 7 | vila franca do campo
# Processing Record 21 of Set 7 | voi
# Processing Record 22 of Set 7 | sao joao da barra
# Processing Record 23 of Set 7 | puerto varas
# Processing Record 24 of Set 7 | windhoek
# Processing Record 25 of Set 7 | palkino
# Processing Record 26 of Set 7 | dukat
# Processing Record 27 of Set 7 | borsad
# Processing Record 28 of Set 7 | lumphat
# Processing Record 29 of Set 7 | iroquois falls
# Processing Record 30 of Set 7 | saint-augustin
# Processing Record 31 of Set 7 | houston
# Processing Record 32 of Set 7 | carutapera
# Processing Record 33 of Set 7 | guanica
# Processing Record 34 of Set 7 | staraya russa
# Processing Record 35 of Set 7 | souillac
# Processing Record 36 of Set 7 | isangel
# Processing Record 37 of Set 7 | pedra azul
# Processing Record 38 of Set 7 | pokrovsk
# Processing Record 39 of Set 7 | fortuna
# Processing Record 40 of Set 7 | murygino
# Processing Record 41 of Set 7 | oranjestad
# Processing Record 42 of Set 7 | sorland
# Processing Record 43 of Set 7 | ormara
# Processing Record 44 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 45 of Set 7 | karratha
# Processing Record 46 of Set 7 | guider
# Processing Record 47 of Set 7 | snyder
# Processing Record 48 of Set 7 | belyy yar
# Processing Record 49 of Set 7 | sola
# Processing Record 50 of Set 7 | pafos
# Processing Record 1 of Set 8 | lokosovo
# Processing Record 2 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 8 | alihe
# Processing Record 4 of Set 8 | kruisfontein
# Processing Record 5 of Set 8 | matara
# Processing Record 6 of Set 8 | merauke
# Processing Record 7 of Set 8 | grindavik
# Processing Record 8 of Set 8 | mandalgovi
# Processing Record 9 of Set 8 | salamanca
# Processing Record 10 of Set 8 | skjervoy
# Processing Record 11 of Set 8 | mizdah
# Processing Record 12 of Set 8 | verkhoyansk
# Processing Record 13 of Set 8 | khadro
# Processing Record 14 of Set 8 | ati
# Processing Record 15 of Set 8 | duiwelskloof
# Processing Record 16 of Set 8 | yarada
# Processing Record 17 of Set 8 | lompoc
# Processing Record 18 of Set 8 | la ronge
# Processing Record 19 of Set 8 | syracuse
# Processing Record 20 of Set 8 | dingle
# Processing Record 21 of Set 8 | alice town
# Processing Record 22 of Set 8 | east london
# Processing Record 23 of Set 8 | breves
# Processing Record 24 of Set 8 | bethel
# Processing Record 25 of Set 8 | baltoji voke
# Processing Record 26 of Set 8 | burns lake
# Processing Record 27 of Set 8 | swan hill
# Processing Record 28 of Set 8 | shimoda
# Processing Record 29 of Set 8 | nouadhibou
# Processing Record 30 of Set 8 | brigantine
# Processing Record 31 of Set 8 | bathsheba
# Processing Record 32 of Set 8 | hami
# Processing Record 33 of Set 8 | grand-santi
# Processing Record 34 of Set 8 | oktyabrskoye
# Processing Record 35 of Set 8 | catumbela
# Processing Record 36 of Set 8 | changji
# Processing Record 37 of Set 8 | nur
# Processing Record 38 of Set 8 | yuli
# Processing Record 39 of Set 8 | karawang
# Processing Record 40 of Set 8 | port elizabeth
# Processing Record 41 of Set 8 | milyutinskaya
# Processing Record 42 of Set 8 | ayan
# Processing Record 43 of Set 8 | hukuntsi
# Processing Record 44 of Set 8 | port macquarie
# Processing Record 45 of Set 8 | vila velha
# Processing Record 46 of Set 8 | letlhakeng
# Processing Record 47 of Set 8 | farah
# Processing Record 48 of Set 8 | jambi
# Processing Record 49 of Set 8 | naliya
# Processing Record 50 of Set 8 | beringovskiy
# Processing Record 1 of Set 9 | yuxia
# Processing Record 2 of Set 9 | flinders
# Processing Record 3 of Set 9 | sangar
# Processing Record 4 of Set 9 | noumea
# Processing Record 5 of Set 9 | wanlaweyn
# Processing Record 6 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 9 | anadyr
# Processing Record 8 of Set 9 | diffa
# Processing Record 9 of Set 9 | adrar
# Processing Record 10 of Set 9 | naze
# Processing Record 11 of Set 9 | waiuku
# Processing Record 12 of Set 9 | baillif
# Processing Record 13 of Set 9 | mogadishu
# Processing Record 14 of Set 9 | opole
# Processing Record 15 of Set 9 | ancud
# Processing Record 16 of Set 9 | blagoyevo
# Processing Record 17 of Set 9 | phuket
# Processing Record 18 of Set 9 | atka
# City not found. Skipping...
# Processing Record 19 of Set 9 | phichit
# Processing Record 20 of Set 9 | leh
# Processing Record 21 of Set 9 | omsukchan
# Processing Record 22 of Set 9 | camana
# Processing Record 23 of Set 9 | tautira
# Processing Record 24 of Set 9 | tshikapa
# Processing Record 25 of Set 9 | haines junction
# Processing Record 26 of Set 9 | oriximina
# Processing Record 27 of Set 9 | caravelas
# Processing Record 28 of Set 9 | zyryanka
# Processing Record 29 of Set 9 | las vegas
# Processing Record 30 of Set 9 | tiarei
# Processing Record 31 of Set 9 | dwarka
# Processing Record 32 of Set 9 | beruwala
# Processing Record 33 of Set 9 | puerto narino
# Processing Record 34 of Set 9 | tuatapere
# Processing Record 35 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 9 | hay river
# Processing Record 37 of Set 9 | manadhoo
# Processing Record 38 of Set 9 | grootfontein
# Processing Record 39 of Set 9 | kenai
# Processing Record 40 of Set 9 | otradnoye
# Processing Record 41 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 9 | camacupa
# Processing Record 43 of Set 9 | vrangel
# Processing Record 44 of Set 9 | lixourion
# Processing Record 45 of Set 9 | haikou
# Processing Record 46 of Set 9 | bubaque
# Processing Record 47 of Set 9 | poronaysk
# Processing Record 48 of Set 9 | provideniya
# Processing Record 49 of Set 9 | moiyabana
# City not found. Skipping...
# Processing Record 50 of Set 9 | charters towers
# Processing Record 1 of Set 10 | itoman
# Processing Record 2 of Set 10 | mnogovershinnyy
# Processing Record 3 of Set 10 | lethem
# Processing Record 4 of Set 10 | okato
# Processing Record 5 of Set 10 | isla mujeres
# Processing Record 6 of Set 10 | iquitos
# Processing Record 7 of Set 10 | tual
# Processing Record 8 of Set 10 | grong
# Processing Record 9 of Set 10 | timizart
# Processing Record 10 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 10 | abu dhabi
# Processing Record 12 of Set 10 | boquira
# Processing Record 13 of Set 10 | katangli
# Processing Record 14 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 15 of Set 10 | tessalit
# Processing Record 16 of Set 10 | fort saint james
# Processing Record 17 of Set 10 | lardos
# Processing Record 18 of Set 10 | kysyl-syr
# Processing Record 19 of Set 10 | ampanihy
# Processing Record 20 of Set 10 | paraiso
# Processing Record 21 of Set 10 | turukhansk
# Processing Record 22 of Set 10 | salalah
# Processing Record 23 of Set 10 | ngunguru
# Processing Record 24 of Set 10 | aykhal
# Processing Record 25 of Set 10 | alyangula
# Processing Record 26 of Set 10 | denpasar
# Processing Record 27 of Set 10 | bandundu
# Processing Record 28 of Set 10 | linxia
# Processing Record 29 of Set 10 | lagoa
# Processing Record 30 of Set 10 | rio gallegos
# Processing Record 31 of Set 10 | galle
# Processing Record 32 of Set 10 | madona
# Processing Record 33 of Set 10 | srednekolymsk
# Processing Record 34 of Set 10 | saint-philippe
# Processing Record 35 of Set 10 | atambua
# Processing Record 36 of Set 10 | kiama
# Processing Record 37 of Set 10 | broken hill
# Processing Record 38 of Set 10 | vanimo
# Processing Record 39 of Set 10 | nardaran
# Processing Record 40 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 10 | faya
# Processing Record 42 of Set 10 | muros
# Processing Record 43 of Set 10 | acajutla
# Processing Record 44 of Set 10 | mulatupo
# Processing Record 45 of Set 10 | daru
# Processing Record 46 of Set 10 | tobermory
# Processing Record 47 of Set 10 | yusva
# City not found. Skipping...
# Processing Record 48 of Set 10 | qasigiannguit
# Processing Record 49 of Set 10 | togur
# Processing Record 50 of Set 10 | havre-saint-pierre
# Processing Record 1 of Set 11 | entre rios
# Processing Record 2 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 11 | beloha
# Processing Record 4 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 5 of Set 11 | azovo
# Processing Record 6 of Set 11 | sim
# Processing Record 7 of Set 11 | altay
# Processing Record 8 of Set 11 | guaraniacu
# Processing Record 9 of Set 11 | kochi
# Processing Record 10 of Set 11 | hamilton
# Processing Record 11 of Set 11 | ilhabela
# Processing Record 12 of Set 11 | colares
# Processing Record 13 of Set 11 | ust-kuyga
# Processing Record 14 of Set 11 | neuquen
# Processing Record 15 of Set 11 | comodoro rivadavia
# Processing Record 16 of Set 11 | winneba
# Processing Record 17 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 11 | jurado
# Processing Record 19 of Set 11 | kudahuvadhoo
# Processing Record 20 of Set 11 | leningradskiy
# Processing Record 21 of Set 11 | tsabong
# Processing Record 22 of Set 11 | acarau
# Processing Record 23 of Set 11 | san quintin
# Processing Record 24 of Set 11 | antofagasta
# Processing Record 25 of Set 11 | shediac
# Processing Record 26 of Set 11 | yukon
# Processing Record 27 of Set 11 | jacqueville
# Processing Record 28 of Set 11 | gari
# Processing Record 29 of Set 11 | gillette
# Processing Record 30 of Set 11 | saint-francois
# Processing Record 31 of Set 11 | parrita
# Processing Record 32 of Set 11 | majene
# Processing Record 33 of Set 11 | oyabe
# Processing Record 34 of Set 11 | menongue
# Processing Record 35 of Set 11 | westport
# Processing Record 36 of Set 11 | hammerfest
# Processing Record 37 of Set 11 | yei
# Processing Record 38 of Set 11 | abha
# Processing Record 39 of Set 11 | zhigansk
# Processing Record 40 of Set 11 | touba
# Processing Record 41 of Set 11 | nagato
# Processing Record 42 of Set 11 | catuday
# Processing Record 43 of Set 11 | sultanpur
# Processing Record 44 of Set 11 | jinxiang
# Processing Record 45 of Set 11 | pedernales
# Processing Record 46 of Set 11 | biak
# Processing Record 47 of Set 11 | raga
# Processing Record 48 of Set 11 | pandan
# Processing Record 49 of Set 11 | kumertau
# Processing Record 50 of Set 11 | honningsvag
# Processing Record 1 of Set 12 | tupelo
# Processing Record 2 of Set 12 | san matias
# Processing Record 3 of Set 12 | goderich
# Processing Record 4 of Set 12 | birao
# Processing Record 5 of Set 12 | kalmunai
# Processing Record 6 of Set 12 | port moresby
# Processing Record 7 of Set 12 | tres passos
# Processing Record 8 of Set 12 | viedma
# Processing Record 9 of Set 12 | penzance
# Processing Record 10 of Set 12 | alice springs
# Processing Record 11 of Set 12 | tabou
# Processing Record 12 of Set 12 | tarauaca
# Processing Record 13 of Set 12 | sao jose da coroa grande
# Processing Record 14 of Set 12 | ust-koksa
# Processing Record 15 of Set 12 | bilma
# Processing Record 16 of Set 12 | jieshi
# Processing Record 17 of Set 12 | safford
# Processing Record 18 of Set 12 | san lorenzo
# Processing Record 19 of Set 12 | fort nelson
# Processing Record 20 of Set 12 | griffith
# Processing Record 21 of Set 12 | luba
# Processing Record 22 of Set 12 | gamba
# Processing Record 23 of Set 12 | sungaipenuh
# Processing Record 24 of Set 12 | mishan
# Processing Record 25 of Set 12 | tete
# Processing Record 26 of Set 12 | vuktyl
# Processing Record 27 of Set 12 | kati
# Processing Record 28 of Set 12 | ambunti
# Processing Record 29 of Set 12 | kulhudhuffushi
# Processing Record 30 of Set 12 | kalengwa
# Processing Record 31 of Set 12 | kholodnyy
# Processing Record 32 of Set 12 | wonji
# City not found. Skipping...
# Processing Record 33 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 12 | hovd
# Processing Record 35 of Set 12 | presidencia roque saenz pena
# Processing Record 36 of Set 12 | mercedes
# Processing Record 37 of Set 12 | tazovskiy
# Processing Record 38 of Set 12 | borogontsy
# Processing Record 39 of Set 12 | suifenhe
# Processing Record 40 of Set 12 | cockburn town
# Processing Record 41 of Set 12 | guerrero negro
# Processing Record 42 of Set 12 | ixhuatan
# Processing Record 43 of Set 12 | boguchany
# Processing Record 44 of Set 12 | bani walid
# Processing Record 45 of Set 12 | morondava
# Processing Record 46 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 12 | betsiamites
# Processing Record 48 of Set 12 | maridi
# Processing Record 49 of Set 12 | katha
# City not found. Skipping...
# Processing Record 50 of Set 12 | bata
# Processing Record 1 of Set 13 | nizhniy ingash
# Processing Record 2 of Set 13 | hobyo
# Processing Record 3 of Set 13 | slawno
# Processing Record 4 of Set 13 | vao
# Processing Record 5 of Set 13 | muzhi
# Processing Record 6 of Set 13 | baykit
# Processing Record 7 of Set 13 | humberto de campos
# Processing Record 8 of Set 13 | tupik
# Processing Record 9 of Set 13 | petropavlovka
# Processing Record 10 of Set 13 | jackson
# Processing Record 11 of Set 13 | gat
# Processing Record 12 of Set 13 | shanghai
# Processing Record 13 of Set 13 | codrington
# Processing Record 14 of Set 13 | porto santo
# Processing Record 15 of Set 13 | mingyue
# Processing Record 16 of Set 13 | high prairie
# Processing Record 17 of Set 13 | fier
# Processing Record 18 of Set 13 | buraydah
# Processing Record 19 of Set 13 | kalaleh
# Processing Record 20 of Set 13 | bambanglipuro
# Processing Record 21 of Set 13 | kihei
# Processing Record 22 of Set 13 | cazaje
# City not found. Skipping...
# Processing Record 23 of Set 13 | mount darwin
# Processing Record 24 of Set 13 | urumqi
# Processing Record 25 of Set 13 | nenjiang
# Processing Record 26 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 27 of Set 13 | gladstone
# Processing Record 28 of Set 13 | scalea
# Processing Record 29 of Set 13 | agirish
# Processing Record 30 of Set 13 | saint-leu
# Processing Record 31 of Set 13 | skibbereen
# Processing Record 32 of Set 13 | manado
# Processing Record 33 of Set 13 | kindu
# Processing Record 34 of Set 13 | tharrawaddy
# City not found. Skipping...
# Processing Record 35 of Set 13 | havoysund
# Processing Record 36 of Set 13 | calama
# Processing Record 37 of Set 13 | komsomolsk
# Processing Record 38 of Set 13 | batagay-alyta
# Processing Record 39 of Set 13 | plettenberg bay
# Processing Record 40 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 13 | oksbol
# Processing Record 43 of Set 13 | juneau
# Processing Record 44 of Set 13 | olafsvik
# Processing Record 45 of Set 13 | road town
# Processing Record 46 of Set 13 | verkhnetulomskiy
# Processing Record 47 of Set 13 | whitehaven
# Processing Record 48 of Set 13 | hirara
# Processing Record 49 of Set 13 | yenagoa
# Processing Record 50 of Set 13 | araouane
# Processing Record 1 of Set 14 | yvetot
# Processing Record 2 of Set 14 | launceston
# Processing Record 3 of Set 14 | onega
# Processing Record 4 of Set 14 | aksu
# Processing Record 5 of Set 14 | troitsk
# Processing Record 6 of Set 14 | biloela
# Processing Record 7 of Set 14 | buala
# Processing Record 8 of Set 14 | hit
# Processing Record 9 of Set 14 | manokwari
# Processing Record 10 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 14 | kiunga
# Processing Record 12 of Set 14 | waitati
# Processing Record 13 of Set 14 | chacabuco
# Processing Record 14 of Set 14 | makakilo city
# Processing Record 15 of Set 14 | udachnyy
# Processing Record 16 of Set 14 | calamar
# Processing Record 17 of Set 14 | nampula
# Processing Record 18 of Set 14 | north bend
# Processing Record 19 of Set 14 | muscle shoals
# Processing Record 20 of Set 14 | landerneau
# Processing Record 21 of Set 14 | aparecida do taboado
# Processing Record 22 of Set 14 | horsham
# Processing Record 23 of Set 14 | graham
# Processing Record 24 of Set 14 | ahipara
# Processing Record 25 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 14 | bilibino
# Processing Record 27 of Set 14 | jacareacanga
# Processing Record 28 of Set 14 | baherden
# Processing Record 29 of Set 14 | avezzano
# Processing Record 30 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 31 of Set 14 | vaitape
# Processing Record 32 of Set 14 | kizema
# Processing Record 33 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 34 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 35 of Set 14 | mangan
# Processing Record 36 of Set 14 | san ramon
# Processing Record 37 of Set 14 | shenjiamen
# Processing Record 38 of Set 14 | calvinia
# Processing Record 39 of Set 14 | guangyuan
# Processing Record 40 of Set 14 | ekibastuz
# Processing Record 41 of Set 14 | morros
# Processing Record 42 of Set 14 | salimpur
# Processing Record 43 of Set 14 | la troncal
# Processing Record 44 of Set 14 | musoma
# Processing Record 45 of Set 14 | caborca
# Processing Record 46 of Set 14 | sovetskiy
# Processing Record 47 of Set 14 | manuk mangkaw
# Processing Record 48 of Set 14 | karaton
# Processing Record 49 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 50 of Set 14 | macamic
# Processing Record 1 of Set 15 | aguia branca
# Processing Record 2 of Set 15 | prijepolje
# Processing Record 3 of Set 15 | chulman
# Processing Record 4 of Set 15 | zhuanghe
# Processing Record 5 of Set 15 | haverfordwest
# Processing Record 6 of Set 15 | porto walter
# Processing Record 7 of Set 15 | paka
# Processing Record 8 of Set 15 | lai
# Processing Record 9 of Set 15 | cauquenes
# Processing Record 10 of Set 15 | antalaha
# Processing Record 11 of Set 15 | toribio
# Processing Record 12 of Set 15 | ust-maya
# Processing Record 13 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 15 | thunder bay
# Processing Record 15 of Set 15 | dingalan
# Processing Record 16 of Set 15 | chengde
# Processing Record 17 of Set 15 | asau
# Processing Record 18 of Set 15 | pithoragarh
# Processing Record 19 of Set 15 | seoul
# Processing Record 20 of Set 15 | kerema
# Processing Record 21 of Set 15 | capreol
# Processing Record 22 of Set 15 | alofi
# Processing Record 23 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 24 of Set 15 | kokorevka
# Processing Record 25 of Set 15 | srandakan
# Processing Record 26 of Set 15 | lingao
# Processing Record 27 of Set 15 | rawson
# Processing Record 28 of Set 15 | saint anthony
# Processing Record 29 of Set 15 | union
# Processing Record 30 of Set 15 | havarna
# Processing Record 31 of Set 15 | hvide sande
# Processing Record 32 of Set 15 | marica
# Processing Record 33 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 15 | alugan
# Processing Record 35 of Set 15 | port keats
# Processing Record 36 of Set 15 | zhezkazgan
# Processing Record 37 of Set 15 | ipixuna
# Processing Record 38 of Set 15 | edson
# Processing Record 39 of Set 15 | amurzet
# Processing Record 40 of Set 15 | leshukonskoye
# Processing Record 41 of Set 15 | coahuayana
# Processing Record 42 of Set 15 | lashio
# Processing Record 43 of Set 15 | arauca
# Processing Record 44 of Set 15 | loandjili
# Processing Record 45 of Set 15 | puerto leguizamo
# Processing Record 46 of Set 15 | thinadhoo
# Processing Record 47 of Set 15 | durant
# Processing Record 48 of Set 15 | valparaiso
# Processing Record 49 of Set 15 | kalcheva
# Processing Record 50 of Set 15 | louga
# Processing Record 1 of Set 16 | fairbanks
# Processing Record 2 of Set 16 | vangaindrano
# Processing Record 3 of Set 16 | nuuk
# Processing Record 4 of Set 16 | paragominas
# Processing Record 5 of Set 16 | andenes
# Processing Record 6 of Set 16 | qingan
# City not found. Skipping...
# Processing Record 7 of Set 16 | minab
# Processing Record 8 of Set 16 | labuan
# Processing Record 9 of Set 16 | bukama
# Processing Record 10 of Set 16 | ozernovskiy
# Processing Record 11 of Set 16 | shieli
# Processing Record 12 of Set 16 | twentynine palms
# Processing Record 13 of Set 16 | vetlanda
# Processing Record 14 of Set 16 | ye
# City not found. Skipping...
# Processing Record 15 of Set 16 | soledad
# Processing Record 16 of Set 16 | sumter
# Processing Record 17 of Set 16 | marshfield
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Cherskiy      RU  68.7500  161.3000    -34.64        99
# 1              Torbay      CA  47.6666  -52.7314     32.95        95
# 2             Camacha      PT  33.0833  -16.3333     68.54        82
# 3              Avarua      CK -21.2078 -159.7750     77.05        83
# 4            Yar-Sale      RU  66.8333   70.8333      6.10        97
# 5           Sirvintos      LT  55.0500   24.9500     29.75        94
# 6          Nanortalik      GL  60.1432  -45.2371     10.89        83
# 7           Sarangani      PH   5.4033  125.4636     80.87        72
# 8           Lake City      US  30.1897  -82.6393     78.85        61
# 9  Sao Felix Do Xingu      BR  -6.6447  -51.9950     90.03        50
#
#    Cloudiness  Wind Speed Current Description
# 0           9        3.80           clear sky
# 1         100       10.36                 fog
# 2          20        3.44          few clouds
# 3          20        4.61          few clouds
# 4         100        2.80          light snow
# 5          98       13.22     overcast clouds
# 6         100       41.96          light snow
# 7         100       20.40     overcast clouds
# 8         100       13.80     overcast clouds
# 9          67        2.66       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
